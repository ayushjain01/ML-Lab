# %% [markdown]
# # Supervised Learning Algorithms - Simple Linear Regression
# Consider any dataset from UCI repository. Create Simple Linear Regression models using the training data set. Predict the scores on the test data and find the error in prediction (E.g. RMSE, MAE, LSE).  Include appropriate code snippets to visualize the model. Use Sub-Plots Interpret the result. Write the Inference.

# %% [markdown]
# #### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Loading dataset

# %%
dataset = pd.read_csv(r'./Datasets/Advertising.csv')
dataset.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Visualizing Given Data

# %%
graphSheet = plt.figure(figsize=(15,10))
graphSheet.add_subplot(3,3,1)
plt.scatter(dataset['TV'],dataset['sales'], c ="orange")
plt.xlabel("Money Spent on TV")
plt.ylabel("sales")
graphSheet.add_subplot(3,3,2)
plt.scatter(dataset['radio'],dataset['sales'],c='pink')
plt.xlabel("Money Spent on Radio")
plt.ylabel("sales")
graphSheet.add_subplot(3,3,3)
plt.scatter(dataset['newspaper'],dataset['sales'],c='teal')
plt.xlabel("Money Spent on Newspaper")
plt.ylabel("sales")
# Out:
# Text(0, 0.5, 'sales')

# %% [markdown]
# #### Splitting the dataset into training and testing set for TV VS Sales

# %%
X_train,x_test,y_train,y_test=train_test_split(dataset["TV"],dataset["sales"],test_size=0.3)
X_train = X_train.to_numpy().reshape(-1,1)
x_test = x_test.to_numpy().reshape(-1,1)
y_train = y_train.to_numpy().reshape(-1,1)
y_test = y_test.to_numpy().reshape(-1,1)

# %% [markdown]
# ### Performing Linear Regression for money spent on TV vs Sales

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predicting

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
# Out:
# [[ 7.1026396 ]
#  [20.79299615]
#  [ 8.63599949]
#  [16.11799661]
#  [10.5089961 ]
#  [13.690593  ]
#  [16.68239292]
#  [10.03949828]
#  [11.09337104]
#  [18.12584897]
#  [10.07945554]
#  [ 7.5971107 ]
#  [ 7.9267581 ]
#  [16.41268141]
#  [21.20755273]
#  [21.40234438]
#  [ 8.11156044]
#  [17.6513565 ]
#  [11.21823748]
#  [ 8.16650167]
#  [13.01631422]
#  [16.71735552]
#  [14.95424138]
#  [21.25749931]
#  [ 9.15044922]
#  [18.45050172]
#  [14.21503205]
#  [12.26711558]
#  [18.69024529]
#  [ 7.70699317]
#  [20.55824724]
#  [12.22216366]
#  [16.9321258 ]
#  [13.4908067 ]
#  [17.61139924]
#  [ 7.1725648 ]
#  [13.79548081]
#  [ 9.54502717]
#  [12.88645313]
#  [10.743745  ]
#  [18.23073678]
#  [18.01596651]
#  [16.85221128]
#  [13.62566245]
#  [16.14796456]
#  [18.71521857]
#  [10.18434335]
#  [10.1543754 ]
#  [13.54075327]
#  [10.26425787]
#  [14.22002671]
#  [ 8.01666194]
#  [15.57857359]
#  [17.54646869]
#  [20.00384024]
#  [15.48367509]
#  [ 9.71484553]
#  [ 7.67203057]
# ...

# %% [markdown]
# #### Visualising

# %%
plt.scatter(X_train,y_train,color = 'orange')
plt.plot(X_train, regressor.predict(X_train), color ='blue')
plt.title('TV vs Sales (Training set)')
plt.xlabel('Money Spent on TV')
plt.ylabel('Sales')
plt.show()
plt.scatter(x_test, y_test, color = 'yellow')
plt.plot(X_train, regressor.predict(X_train), color = 'green')
plt.title('TV vs Sales (Training set)')
plt.xlabel('Money Spent on TV')
plt.ylabel('Sales')
plt.show()

# %%
mse=mean_squared_error(y_test,y_pred)
rmse=(mse)**(1/2)
rsq = r2_score(y_test,y_pred)
print("MSE : ", mse)
print("RSQ : ",rsq)
# Out:
# MSE :  10.390053908515982
# RSQ :  0.5337295846238574
